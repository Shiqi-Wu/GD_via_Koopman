# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
# font-size: 22px;
# </style>
# Out:
# <style type='text/css'>
# .CodeMirror{
# font-size: 22px;
# </style>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.debugging.set_log_device_placement(False)
gpus = tf.config.list_physical_devices('GPU')
# Out:
# 2023-03-21 13:31:53.230984: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-21 13:31:53.358639: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-03-21 13:31:53.975312: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-03-21 13:31:53.975372: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-03-21 13:31:53.975377: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1

# %%
from sklearn.decomposition import PCA
import numpy as np
import tensorflow as tf

# Load MNIST data.
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Preprocessing: normalize pixel values to be between 0 and 1.
x_train = x_train / 255.0
x_test = x_test / 255.0

# Shuffle training data.
shuffle_index = np.random.permutation(len(x_train))
x_train, y_train = x_train[shuffle_index], y_train[shuffle_index]

# Convert target labels to binary classification (digit < 5 or digit >= 5).
y_train = (y_train < 5)
y_test = (y_test < 5)

# Convert labels to one-hot encoding.
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Track the data type of x_train.
dataType = x_train.dtype
print(f"Data type: {dataType}")

# Track the data type of y_test.
labelType = y_test.dtype
print(f"Data type: {labelType}")

# Print the one-hot encoded label for the first training example.
print(y_train[0])

# Instantiate the training dataset.
x_train = np.reshape(x_train, (-1, 784))
x_test = np.reshape(x_test, (-1, 784))

# Perform PCA to reduce dimensionality of x_train.
pca = PCA(n_components=0.7)  # retain 95% of variance
x_train_reduced = pca.fit_transform(x_train.reshape(x_train.shape[0], -1))
x_test_reduced = pca.transform(x_test.reshape(x_test.shape[0], -1))

# Print the dimensions of the original and reduced datasets.
print("Original dimensions:", x_train.shape)
print("Reduced dimensions:", x_train_reduced.shape)
# Out:
# Data type: float64
# Data type: float32
# [0. 1.]
# Original dimensions: (60000, 784)
# Reduced dimensions: (60000, 26)

# %%
from tensorflow import keras
inputs = keras.Input(shape=(26,), name="digits")
x = keras.layers.Dense(1024, activation="relu", kernel_initializer="uniform",bias_initializer="uniform")(inputs)
# x = keras.layers.Dense(128, activation="relu", kernel_initializer="uniform",bias_initializer="uniform")(x)
outputs = keras.layers.Dense(2, name="predictions",kernel_initializer="uniform",bias_initializer="uniform")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  digits (InputLayer)         [(None, 26)]              0
#
#  dense_21 (Dense)            (None, 1024)              27648
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 29,698
# Trainable params: 29,698
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Instantiate an optimizer.
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
# Instantiate a loss function.
loss_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
# Compile the model
model.compile(optimizer=optimizer, loss=loss_fn,  metrics=["accuracy"])

# %%
history = model.fit(x_train_reduced, y_train, validation_data=(x_test_reduced, y_test), batch_size=128, epochs=1000, verbose=2)
# Out:
# Epoch 1/1000
# 469/469 - 2s - loss: 0.6375 - accuracy: 0.6881 - val_loss: 0.5428 - val_accuracy: 0.7785 - 2s/epoch - 5ms/step
# Epoch 2/1000
# 469/469 - 2s - loss: 0.4656 - accuracy: 0.7961 - val_loss: 0.3911 - val_accuracy: 0.8270 - 2s/epoch - 4ms/step
# Epoch 3/1000
# 469/469 - 2s - loss: 0.3632 - accuracy: 0.8440 - val_loss: 0.3200 - val_accuracy: 0.8674 - 2s/epoch - 4ms/step
# Epoch 4/1000
# 469/469 - 2s - loss: 0.3057 - accuracy: 0.8809 - val_loss: 0.2734 - val_accuracy: 0.8965 - 2s/epoch - 4ms/step
# Epoch 5/1000
# 469/469 - 2s - loss: 0.2656 - accuracy: 0.9020 - val_loss: 0.2414 - val_accuracy: 0.9118 - 2s/epoch - 4ms/step
# Epoch 6/1000
# 469/469 - 2s - loss: 0.2378 - accuracy: 0.9141 - val_loss: 0.2195 - val_accuracy: 0.9203 - 2s/epoch - 4ms/step
# Epoch 7/1000
# 469/469 - 2s - loss: 0.2182 - accuracy: 0.9223 - val_loss: 0.2042 - val_accuracy: 0.9270 - 2s/epoch - 4ms/step
# Epoch 8/1000
# 469/469 - 2s - loss: 0.2040 - accuracy: 0.9280 - val_loss: 0.1930 - val_accuracy: 0.9324 - 2s/epoch - 4ms/step
# Epoch 9/1000
# 469/469 - 2s - loss: 0.1931 - accuracy: 0.9319 - val_loss: 0.1845 - val_accuracy: 0.9350 - 2s/epoch - 4ms/step
# Epoch 10/1000
# 469/469 - 2s - loss: 0.1844 - accuracy: 0.9350 - val_loss: 0.1772 - val_accuracy: 0.9380 - 2s/epoch - 4ms/step
# Epoch 11/1000
# 469/469 - 2s - loss: 0.1771 - accuracy: 0.9378 - val_loss: 0.1710 - val_accuracy: 0.9397 - 2s/epoch - 4ms/step
# Epoch 12/1000
# 469/469 - 2s - loss: 0.1707 - accuracy: 0.9399 - val_loss: 0.1655 - val_accuracy: 0.9426 - 2s/epoch - 4ms/step
# Epoch 13/1000
# 469/469 - 2s - loss: 0.1652 - accuracy: 0.9417 - val_loss: 0.1610 - val_accuracy: 0.9437 - 2s/epoch - 4ms/step
# Epoch 14/1000
# 469/469 - 2s - loss: 0.1602 - accuracy: 0.9440 - val_loss: 0.1569 - val_accuracy: 0.9448 - 2s/epoch - 4ms/step
# Epoch 15/1000
# 469/469 - 2s - loss: 0.1556 - accuracy: 0.9461 - val_loss: 0.1526 - val_accuracy: 0.9461 - 2s/epoch - 4ms/step
# Epoch 16/1000
# 469/469 - 2s - loss: 0.1514 - accuracy: 0.9476 - val_loss: 0.1490 - val_accuracy: 0.9483 - 2s/epoch - 4ms/step
# Epoch 17/1000
# 469/469 - 2s - loss: 0.1475 - accuracy: 0.9489 - val_loss: 0.1458 - val_accuracy: 0.9503 - 2s/epoch - 4ms/step
# Epoch 18/1000
# 469/469 - 2s - loss: 0.1440 - accuracy: 0.9504 - val_loss: 0.1422 - val_accuracy: 0.9509 - 2s/epoch - 4ms/step
# Epoch 19/1000
# 469/469 - 2s - loss: 0.1406 - accuracy: 0.9518 - val_loss: 0.1395 - val_accuracy: 0.9516 - 2s/epoch - 4ms/step
# Epoch 20/1000
# 469/469 - 2s - loss: 0.1376 - accuracy: 0.9528 - val_loss: 0.1368 - val_accuracy: 0.9530 - 2s/epoch - 4ms/step
# Epoch 21/1000
# 469/469 - 2s - loss: 0.1348 - accuracy: 0.9538 - val_loss: 0.1340 - val_accuracy: 0.9541 - 2s/epoch - 4ms/step
# Epoch 22/1000
# 469/469 - 2s - loss: 0.1322 - accuracy: 0.9546 - val_loss: 0.1316 - val_accuracy: 0.9542 - 2s/epoch - 4ms/step
# Epoch 23/1000
# 469/469 - 2s - loss: 0.1297 - accuracy: 0.9557 - val_loss: 0.1296 - val_accuracy: 0.9553 - 2s/epoch - 4ms/step
# Epoch 24/1000
# 469/469 - 2s - loss: 0.1275 - accuracy: 0.9566 - val_loss: 0.1274 - val_accuracy: 0.9566 - 2s/epoch - 4ms/step
# Epoch 25/1000
# 469/469 - 2s - loss: 0.1254 - accuracy: 0.9573 - val_loss: 0.1257 - val_accuracy: 0.9570 - 2s/epoch - 4ms/step
# Epoch 26/1000
# 469/469 - 2s - loss: 0.1234 - accuracy: 0.9582 - val_loss: 0.1238 - val_accuracy: 0.9569 - 2s/epoch - 4ms/step
# Epoch 27/1000
# 469/469 - 2s - loss: 0.1215 - accuracy: 0.9588 - val_loss: 0.1222 - val_accuracy: 0.9581 - 2s/epoch - 4ms/step
# Epoch 28/1000
# 469/469 - 2s - loss: 0.1198 - accuracy: 0.9593 - val_loss: 0.1210 - val_accuracy: 0.9588 - 2s/epoch - 4ms/step
# Epoch 29/1000
# 469/469 - 2s - loss: 0.1181 - accuracy: 0.9597 - val_loss: 0.1194 - val_accuracy: 0.9593 - 2s/epoch - 4ms/step
# Epoch 30/1000
# 469/469 - 2s - loss: 0.1166 - accuracy: 0.9606 - val_loss: 0.1180 - val_accuracy: 0.9595 - 2s/epoch - 4ms/step
# Epoch 31/1000
# 469/469 - 2s - loss: 0.1152 - accuracy: 0.9607 - val_loss: 0.1168 - val_accuracy: 0.9597 - 2s/epoch - 4ms/step
# Epoch 32/1000
# 469/469 - 2s - loss: 0.1138 - accuracy: 0.9615 - val_loss: 0.1152 - val_accuracy: 0.9602 - 2s/epoch - 4ms/step
# Epoch 33/1000
# 469/469 - 2s - loss: 0.1125 - accuracy: 0.9618 - val_loss: 0.1142 - val_accuracy: 0.9603 - 2s/epoch - 4ms/step
# Epoch 34/1000
# 469/469 - 2s - loss: 0.1112 - accuracy: 0.9624 - val_loss: 0.1135 - val_accuracy: 0.9604 - 2s/epoch - 4ms/step
# Epoch 35/1000
# 469/469 - 2s - loss: 0.1101 - accuracy: 0.9625 - val_loss: 0.1123 - val_accuracy: 0.9612 - 2s/epoch - 4ms/step
# Epoch 36/1000
# 469/469 - 2s - loss: 0.1089 - accuracy: 0.9634 - val_loss: 0.1114 - val_accuracy: 0.9617 - 2s/epoch - 4ms/step
# Epoch 37/1000
# 469/469 - 2s - loss: 0.1078 - accuracy: 0.9636 - val_loss: 0.1105 - val_accuracy: 0.9608 - 2s/epoch - 4ms/step
# Epoch 38/1000
# 469/469 - 2s - loss: 0.1068 - accuracy: 0.9639 - val_loss: 0.1099 - val_accuracy: 0.9625 - 2s/epoch - 4ms/step
# Epoch 39/1000
# 469/469 - 2s - loss: 0.1059 - accuracy: 0.9641 - val_loss: 0.1092 - val_accuracy: 0.9627 - 2s/epoch - 4ms/step
# Epoch 40/1000
# 469/469 - 2s - loss: 0.1049 - accuracy: 0.9643 - val_loss: 0.1082 - val_accuracy: 0.9628 - 2s/epoch - 4ms/step
# Epoch 41/1000
# 469/469 - 2s - loss: 0.1040 - accuracy: 0.9646 - val_loss: 0.1073 - val_accuracy: 0.9636 - 2s/epoch - 4ms/step
# Epoch 42/1000
# 469/469 - 2s - loss: 0.1031 - accuracy: 0.9651 - val_loss: 0.1064 - val_accuracy: 0.9635 - 2s/epoch - 4ms/step
# Epoch 43/1000
# 469/469 - 2s - loss: 0.1022 - accuracy: 0.9653 - val_loss: 0.1059 - val_accuracy: 0.9644 - 2s/epoch - 4ms/step
# Epoch 44/1000
# 469/469 - 2s - loss: 0.1014 - accuracy: 0.9656 - val_loss: 0.1053 - val_accuracy: 0.9642 - 2s/epoch - 4ms/step
# Epoch 45/1000
# 469/469 - 2s - loss: 0.1005 - accuracy: 0.9657 - val_loss: 0.1046 - val_accuracy: 0.9641 - 2s/epoch - 4ms/step
# Epoch 46/1000
# 469/469 - 2s - loss: 0.0998 - accuracy: 0.9661 - val_loss: 0.1041 - val_accuracy: 0.9643 - 2s/epoch - 4ms/step
# Epoch 47/1000
# 469/469 - 2s - loss: 0.0991 - accuracy: 0.9661 - val_loss: 0.1034 - val_accuracy: 0.9651 - 2s/epoch - 4ms/step
# Epoch 48/1000
# 469/469 - 2s - loss: 0.0983 - accuracy: 0.9664 - val_loss: 0.1028 - val_accuracy: 0.9654 - 2s/epoch - 4ms/step
# Epoch 49/1000
# 469/469 - 2s - loss: 0.0977 - accuracy: 0.9664 - val_loss: 0.1025 - val_accuracy: 0.9651 - 2s/epoch - 4ms/step
# Epoch 50/1000
# 469/469 - 2s - loss: 0.0969 - accuracy: 0.9669 - val_loss: 0.1018 - val_accuracy: 0.9660 - 2s/epoch - 4ms/step
# Epoch 51/1000
# 469/469 - 2s - loss: 0.0962 - accuracy: 0.9671 - val_loss: 0.1012 - val_accuracy: 0.9663 - 2s/epoch - 4ms/step
# Epoch 52/1000
# 469/469 - 2s - loss: 0.0956 - accuracy: 0.9675 - val_loss: 0.1007 - val_accuracy: 0.9659 - 2s/epoch - 4ms/step
# Epoch 53/1000
# 469/469 - 2s - loss: 0.0950 - accuracy: 0.9679 - val_loss: 0.1001 - val_accuracy: 0.9663 - 2s/epoch - 4ms/step
# Epoch 54/1000
# 469/469 - 2s - loss: 0.0943 - accuracy: 0.9676 - val_loss: 0.0999 - val_accuracy: 0.9658 - 2s/epoch - 4ms/step
# Epoch 55/1000
# 469/469 - 2s - loss: 0.0937 - accuracy: 0.9679 - val_loss: 0.0992 - val_accuracy: 0.9665 - 2s/epoch - 4ms/step
# Epoch 56/1000
# 469/469 - 2s - loss: 0.0931 - accuracy: 0.9683 - val_loss: 0.0987 - val_accuracy: 0.9674 - 2s/epoch - 4ms/step
# Epoch 57/1000
# 469/469 - 2s - loss: 0.0925 - accuracy: 0.9682 - val_loss: 0.0983 - val_accuracy: 0.9666 - 2s/epoch - 4ms/step
# Epoch 58/1000
# 469/469 - 2s - loss: 0.0919 - accuracy: 0.9685 - val_loss: 0.0981 - val_accuracy: 0.9670 - 2s/epoch - 4ms/step
# Epoch 59/1000
# 469/469 - 2s - loss: 0.0914 - accuracy: 0.9686 - val_loss: 0.0973 - val_accuracy: 0.9675 - 2s/epoch - 4ms/step
# Epoch 60/1000
# 469/469 - 2s - loss: 0.0908 - accuracy: 0.9694 - val_loss: 0.0968 - val_accuracy: 0.9675 - 2s/epoch - 4ms/step
# Epoch 61/1000
# 469/469 - 2s - loss: 0.0903 - accuracy: 0.9692 - val_loss: 0.0965 - val_accuracy: 0.9683 - 2s/epoch - 4ms/step
# Epoch 62/1000
# 469/469 - 2s - loss: 0.0898 - accuracy: 0.9693 - val_loss: 0.0962 - val_accuracy: 0.9676 - 2s/epoch - 4ms/step
# Epoch 63/1000
# 469/469 - 2s - loss: 0.0892 - accuracy: 0.9695 - val_loss: 0.0959 - val_accuracy: 0.9675 - 2s/epoch - 4ms/step
# Epoch 64/1000
# 469/469 - 2s - loss: 0.0887 - accuracy: 0.9694 - val_loss: 0.0952 - val_accuracy: 0.9682 - 2s/epoch - 4ms/step
# Epoch 65/1000
# 469/469 - 2s - loss: 0.0881 - accuracy: 0.9696 - val_loss: 0.0949 - val_accuracy: 0.9684 - 2s/epoch - 4ms/step
# Epoch 66/1000
# 469/469 - 2s - loss: 0.0877 - accuracy: 0.9701 - val_loss: 0.0944 - val_accuracy: 0.9683 - 2s/epoch - 4ms/step
# Epoch 67/1000
# 469/469 - 2s - loss: 0.0872 - accuracy: 0.9700 - val_loss: 0.0943 - val_accuracy: 0.9674 - 2s/epoch - 4ms/step
# Epoch 68/1000
# 469/469 - 2s - loss: 0.0867 - accuracy: 0.9704 - val_loss: 0.0940 - val_accuracy: 0.9673 - 2s/epoch - 4ms/step
# Epoch 69/1000
# 469/469 - 2s - loss: 0.0863 - accuracy: 0.9702 - val_loss: 0.0935 - val_accuracy: 0.9682 - 2s/epoch - 4ms/step
# Epoch 70/1000
# 469/469 - 2s - loss: 0.0858 - accuracy: 0.9707 - val_loss: 0.0933 - val_accuracy: 0.9685 - 2s/epoch - 4ms/step
# Epoch 71/1000
# 469/469 - 2s - loss: 0.0853 - accuracy: 0.9705 - val_loss: 0.0930 - val_accuracy: 0.9676 - 2s/epoch - 4ms/step
# Epoch 72/1000
# 469/469 - 2s - loss: 0.0849 - accuracy: 0.9711 - val_loss: 0.0925 - val_accuracy: 0.9686 - 2s/epoch - 4ms/step
# Epoch 73/1000
# 469/469 - 2s - loss: 0.0845 - accuracy: 0.9713 - val_loss: 0.0924 - val_accuracy: 0.9686 - 2s/epoch - 4ms/step
# Epoch 74/1000
# 469/469 - 2s - loss: 0.0840 - accuracy: 0.9711 - val_loss: 0.0924 - val_accuracy: 0.9680 - 2s/epoch - 4ms/step
# Epoch 75/1000
# 469/469 - 2s - loss: 0.0836 - accuracy: 0.9713 - val_loss: 0.0919 - val_accuracy: 0.9683 - 2s/epoch - 4ms/step
# Epoch 76/1000
# 469/469 - 2s - loss: 0.0831 - accuracy: 0.9714 - val_loss: 0.0917 - val_accuracy: 0.9681 - 2s/epoch - 4ms/step
# Epoch 77/1000
# 469/469 - 2s - loss: 0.0827 - accuracy: 0.9718 - val_loss: 0.0913 - val_accuracy: 0.9682 - 2s/epoch - 4ms/step
# Epoch 78/1000
# 469/469 - 2s - loss: 0.0823 - accuracy: 0.9717 - val_loss: 0.0909 - val_accuracy: 0.9688 - 2s/epoch - 4ms/step
# Epoch 79/1000
# 469/469 - 2s - loss: 0.0819 - accuracy: 0.9719 - val_loss: 0.0906 - val_accuracy: 0.9692 - 2s/epoch - 4ms/step
# Epoch 80/1000
# 469/469 - 2s - loss: 0.0815 - accuracy: 0.9720 - val_loss: 0.0907 - val_accuracy: 0.9682 - 2s/epoch - 4ms/step
# Epoch 81/1000
# 469/469 - 2s - loss: 0.0812 - accuracy: 0.9719 - val_loss: 0.0899 - val_accuracy: 0.9682 - 2s/epoch - 4ms/step
# Epoch 82/1000
# 469/469 - 2s - loss: 0.0807 - accuracy: 0.9724 - val_loss: 0.0907 - val_accuracy: 0.9683 - 2s/epoch - 4ms/step
# Epoch 83/1000
# 469/469 - 2s - loss: 0.0804 - accuracy: 0.9728 - val_loss: 0.0893 - val_accuracy: 0.9691 - 2s/epoch - 4ms/step
# Epoch 84/1000
# 469/469 - 2s - loss: 0.0800 - accuracy: 0.9723 - val_loss: 0.0892 - val_accuracy: 0.9687 - 2s/epoch - 4ms/step
# Epoch 85/1000
# 469/469 - 2s - loss: 0.0796 - accuracy: 0.9727 - val_loss: 0.0888 - val_accuracy: 0.9682 - 2s/epoch - 4ms/step
# Epoch 86/1000
# 469/469 - 2s - loss: 0.0793 - accuracy: 0.9729 - val_loss: 0.0885 - val_accuracy: 0.9690 - 2s/epoch - 4ms/step
# Epoch 87/1000
# 469/469 - 2s - loss: 0.0790 - accuracy: 0.9732 - val_loss: 0.0881 - val_accuracy: 0.9696 - 2s/epoch - 4ms/step
# Epoch 88/1000
# 469/469 - 2s - loss: 0.0786 - accuracy: 0.9731 - val_loss: 0.0880 - val_accuracy: 0.9692 - 2s/epoch - 4ms/step
# Epoch 89/1000
# 469/469 - 2s - loss: 0.0783 - accuracy: 0.9731 - val_loss: 0.0882 - val_accuracy: 0.9690 - 2s/epoch - 4ms/step
# Epoch 90/1000
# 469/469 - 2s - loss: 0.0780 - accuracy: 0.9733 - val_loss: 0.0877 - val_accuracy: 0.9693 - 2s/epoch - 4ms/step
# Epoch 91/1000
# 469/469 - 2s - loss: 0.0776 - accuracy: 0.9733 - val_loss: 0.0874 - val_accuracy: 0.9694 - 2s/epoch - 4ms/step
# Epoch 92/1000
# 469/469 - 2s - loss: 0.0773 - accuracy: 0.9734 - val_loss: 0.0870 - val_accuracy: 0.9697 - 2s/epoch - 4ms/step
# Epoch 93/1000
# 469/469 - 2s - loss: 0.0770 - accuracy: 0.9737 - val_loss: 0.0867 - val_accuracy: 0.9701 - 2s/epoch - 4ms/step
# Epoch 94/1000
# 469/469 - 2s - loss: 0.0766 - accuracy: 0.9736 - val_loss: 0.0867 - val_accuracy: 0.9703 - 2s/epoch - 4ms/step
# Epoch 95/1000
# 469/469 - 2s - loss: 0.0764 - accuracy: 0.9737 - val_loss: 0.0864 - val_accuracy: 0.9704 - 2s/epoch - 4ms/step
# Epoch 96/1000
# 469/469 - 2s - loss: 0.0761 - accuracy: 0.9738 - val_loss: 0.0857 - val_accuracy: 0.9697 - 2s/epoch - 4ms/step
# Epoch 97/1000
# 469/469 - 2s - loss: 0.0758 - accuracy: 0.9742 - val_loss: 0.0859 - val_accuracy: 0.9705 - 2s/epoch - 4ms/step
# Epoch 98/1000
# 469/469 - 2s - loss: 0.0754 - accuracy: 0.9740 - val_loss: 0.0863 - val_accuracy: 0.9691 - 2s/epoch - 4ms/step
# Epoch 99/1000
# 469/469 - 2s - loss: 0.0752 - accuracy: 0.9741 - val_loss: 0.0856 - val_accuracy: 0.9703 - 2s/epoch - 4ms/step
# Epoch 100/1000
# 469/469 - 2s - loss: 0.0749 - accuracy: 0.9743 - val_loss: 0.0853 - val_accuracy: 0.9706 - 2s/epoch - 4ms/step
# Epoch 101/1000
# 469/469 - 2s - loss: 0.0746 - accuracy: 0.9745 - val_loss: 0.0850 - val_accuracy: 0.9706 - 2s/epoch - 4ms/step
# Epoch 102/1000
# 469/469 - 2s - loss: 0.0743 - accuracy: 0.9746 - val_loss: 0.0850 - val_accuracy: 0.9712 - 2s/epoch - 4ms/step
# Epoch 103/1000
# 469/469 - 2s - loss: 0.0740 - accuracy: 0.9746 - val_loss: 0.0846 - val_accuracy: 0.9710 - 2s/epoch - 4ms/step
# Epoch 104/1000
# 469/469 - 2s - loss: 0.0737 - accuracy: 0.9746 - val_loss: 0.0849 - val_accuracy: 0.9706 - 2s/epoch - 4ms/step
# Epoch 105/1000
# 469/469 - 2s - loss: 0.0735 - accuracy: 0.9747 - val_loss: 0.0844 - val_accuracy: 0.9706 - 2s/epoch - 4ms/step
# Epoch 106/1000
# 469/469 - 2s - loss: 0.0732 - accuracy: 0.9748 - val_loss: 0.0843 - val_accuracy: 0.9706 - 2s/epoch - 4ms/step
# Epoch 107/1000
# 469/469 - 2s - loss: 0.0729 - accuracy: 0.9748 - val_loss: 0.0844 - val_accuracy: 0.9714 - 2s/epoch - 4ms/step
# Epoch 108/1000
# 469/469 - 2s - loss: 0.0727 - accuracy: 0.9750 - val_loss: 0.0841 - val_accuracy: 0.9705 - 2s/epoch - 4ms/step
# Epoch 109/1000
# 469/469 - 2s - loss: 0.0724 - accuracy: 0.9749 - val_loss: 0.0839 - val_accuracy: 0.9710 - 2s/epoch - 4ms/step
# Epoch 110/1000
# 469/469 - 2s - loss: 0.0722 - accuracy: 0.9753 - val_loss: 0.0839 - val_accuracy: 0.9712 - 2s/epoch - 4ms/step
# Epoch 111/1000
# 469/469 - 2s - loss: 0.0718 - accuracy: 0.9756 - val_loss: 0.0838 - val_accuracy: 0.9706 - 2s/epoch - 4ms/step
# Epoch 112/1000
# 469/469 - 2s - loss: 0.0716 - accuracy: 0.9754 - val_loss: 0.0836 - val_accuracy: 0.9714 - 2s/epoch - 4ms/step
# Epoch 113/1000
# 469/469 - 2s - loss: 0.0714 - accuracy: 0.9754 - val_loss: 0.0835 - val_accuracy: 0.9713 - 2s/epoch - 4ms/step
# Epoch 114/1000
# 469/469 - 2s - loss: 0.0711 - accuracy: 0.9757 - val_loss: 0.0830 - val_accuracy: 0.9716 - 2s/epoch - 4ms/step
# Epoch 115/1000
# 469/469 - 2s - loss: 0.0708 - accuracy: 0.9757 - val_loss: 0.0835 - val_accuracy: 0.9719 - 2s/epoch - 4ms/step
# Epoch 116/1000
# 469/469 - 2s - loss: 0.0707 - accuracy: 0.9754 - val_loss: 0.0828 - val_accuracy: 0.9715 - 2s/epoch - 4ms/step
# Epoch 117/1000
# 469/469 - 2s - loss: 0.0704 - accuracy: 0.9760 - val_loss: 0.0829 - val_accuracy: 0.9717 - 2s/epoch - 4ms/step
# Epoch 118/1000
# 469/469 - 2s - loss: 0.0702 - accuracy: 0.9761 - val_loss: 0.0828 - val_accuracy: 0.9710 - 2s/epoch - 4ms/step
# Epoch 119/1000
# 469/469 - 2s - loss: 0.0700 - accuracy: 0.9760 - val_loss: 0.0826 - val_accuracy: 0.9717 - 2s/epoch - 4ms/step
# Epoch 120/1000
# 469/469 - 2s - loss: 0.0697 - accuracy: 0.9759 - val_loss: 0.0827 - val_accuracy: 0.9725 - 2s/epoch - 4ms/step
# Epoch 121/1000
# 469/469 - 2s - loss: 0.0695 - accuracy: 0.9762 - val_loss: 0.0821 - val_accuracy: 0.9722 - 2s/epoch - 4ms/step
# Epoch 122/1000
# 469/469 - 2s - loss: 0.0693 - accuracy: 0.9762 - val_loss: 0.0822 - val_accuracy: 0.9722 - 2s/epoch - 4ms/step
# Epoch 123/1000
# 469/469 - 2s - loss: 0.0691 - accuracy: 0.9762 - val_loss: 0.0820 - val_accuracy: 0.9725 - 2s/epoch - 4ms/step
# Epoch 124/1000
# 469/469 - 2s - loss: 0.0687 - accuracy: 0.9765 - val_loss: 0.0818 - val_accuracy: 0.9715 - 2s/epoch - 4ms/step
# Epoch 125/1000
# 469/469 - 2s - loss: 0.0686 - accuracy: 0.9764 - val_loss: 0.0822 - val_accuracy: 0.9717 - 2s/epoch - 4ms/step
# Epoch 126/1000
# 469/469 - 2s - loss: 0.0684 - accuracy: 0.9767 - val_loss: 0.0817 - val_accuracy: 0.9718 - 2s/epoch - 4ms/step
# Epoch 127/1000
# 469/469 - 2s - loss: 0.0682 - accuracy: 0.9765 - val_loss: 0.0814 - val_accuracy: 0.9722 - 2s/epoch - 4ms/step
# Epoch 128/1000
# 469/469 - 2s - loss: 0.0680 - accuracy: 0.9767 - val_loss: 0.0812 - val_accuracy: 0.9721 - 2s/epoch - 4ms/step
# Epoch 129/1000
# Epoch 166/1000
# 469/469 - 2s - loss: 0.0612 - accuracy: 0.9784 - val_loss: 0.0774 - val_accuracy: 0.9741 - 2s/epoch - 4ms/step
# Epoch 167/1000
# 469/469 - 2s - loss: 0.0609 - accuracy: 0.9786 - val_loss: 0.0776 - val_accuracy: 0.9734 - 2s/epoch - 4ms/step
# Epoch 168/1000
# 469/469 - 2s - loss: 0.0608 - accuracy: 0.9791 - val_loss: 0.0772 - val_accuracy: 0.9735 - 2s/epoch - 4ms/step
# Epoch 169/1000
# 469/469 - 2s - loss: 0.0606 - accuracy: 0.9789 - val_loss: 0.0772 - val_accuracy: 0.9741 - 2s/epoch - 4ms/step
# Epoch 170/1000
# 469/469 - 2s - loss: 0.0606 - accuracy: 0.9790 - val_loss: 0.0774 - val_accuracy: 0.9735 - 2s/epoch - 4ms/step
# Epoch 171/1000
# 469/469 - 2s - loss: 0.0603 - accuracy: 0.9790 - val_loss: 0.0769 - val_accuracy: 0.9736 - 2s/epoch - 4ms/step
# Epoch 172/1000
# 469/469 - 2s - loss: 0.0602 - accuracy: 0.9793 - val_loss: 0.0772 - val_accuracy: 0.9737 - 2s/epoch - 4ms/step
# Epoch 173/1000
# 469/469 - 2s - loss: 0.0600 - accuracy: 0.9791 - val_loss: 0.0771 - val_accuracy: 0.9735 - 2s/epoch - 4ms/step
# Epoch 174/1000
# 469/469 - 2s - loss: 0.0599 - accuracy: 0.9793 - val_loss: 0.0767 - val_accuracy: 0.9741 - 2s/epoch - 4ms/step
# Epoch 175/1000
# 469/469 - 2s - loss: 0.0598 - accuracy: 0.9793 - val_loss: 0.0767 - val_accuracy: 0.9742 - 2s/epoch - 4ms/step
# Epoch 176/1000
# 469/469 - 2s - loss: 0.0596 - accuracy: 0.9797 - val_loss: 0.0765 - val_accuracy: 0.9731 - 2s/epoch - 4ms/step
# Epoch 177/1000
# 469/469 - 2s - loss: 0.0595 - accuracy: 0.9793 - val_loss: 0.0767 - val_accuracy: 0.9741 - 2s/epoch - 4ms/step
# Epoch 178/1000
# 469/469 - 2s - loss: 0.0593 - accuracy: 0.9793 - val_loss: 0.0760 - val_accuracy: 0.9742 - 2s/epoch - 4ms/step
# Epoch 179/1000
# 469/469 - 2s - loss: 0.0591 - accuracy: 0.9794 - val_loss: 0.0760 - val_accuracy: 0.9745 - 2s/epoch - 4ms/step
# Epoch 180/1000
# 469/469 - 2s - loss: 0.0591 - accuracy: 0.9797 - val_loss: 0.0762 - val_accuracy: 0.9740 - 2s/epoch - 4ms/step
# Epoch 181/1000
# 469/469 - 2s - loss: 0.0589 - accuracy: 0.9797 - val_loss: 0.0760 - val_accuracy: 0.9735 - 2s/epoch - 4ms/step
# Epoch 182/1000
# 469/469 - 2s - loss: 0.0588 - accuracy: 0.9797 - val_loss: 0.0762 - val_accuracy: 0.9740 - 2s/epoch - 4ms/step
# Epoch 183/1000
# 469/469 - 2s - loss: 0.0586 - accuracy: 0.9796 - val_loss: 0.0760 - val_accuracy: 0.9740 - 2s/epoch - 4ms/step
# Epoch 184/1000
# 469/469 - 2s - loss: 0.0585 - accuracy: 0.9796 - val_loss: 0.0758 - val_accuracy: 0.9744 - 2s/epoch - 4ms/step
# Epoch 185/1000
# 469/469 - 2s - loss: 0.0584 - accuracy: 0.9796 - val_loss: 0.0760 - val_accuracy: 0.9743 - 2s/epoch - 4ms/step
# Epoch 186/1000
# 469/469 - 2s - loss: 0.0582 - accuracy: 0.9800 - val_loss: 0.0756 - val_accuracy: 0.9739 - 2s/epoch - 4ms/step
# Epoch 187/1000
# 469/469 - 2s - loss: 0.0581 - accuracy: 0.9797 - val_loss: 0.0760 - val_accuracy: 0.9737 - 2s/epoch - 4ms/step
# Epoch 188/1000
# 469/469 - 2s - loss: 0.0580 - accuracy: 0.9799 - val_loss: 0.0755 - val_accuracy: 0.9743 - 2s/epoch - 4ms/step
# Epoch 189/1000
# 469/469 - 2s - loss: 0.0578 - accuracy: 0.9798 - val_loss: 0.0754 - val_accuracy: 0.9739 - 2s/epoch - 4ms/step
# Epoch 190/1000
# 469/469 - 2s - loss: 0.0578 - accuracy: 0.9798 - val_loss: 0.0754 - val_accuracy: 0.9740 - 2s/epoch - 4ms/step
# Epoch 191/1000
# 469/469 - 2s - loss: 0.0575 - accuracy: 0.9803 - val_loss: 0.0755 - val_accuracy: 0.9739 - 2s/epoch - 4ms/step
# Epoch 192/1000
# 469/469 - 2s - loss: 0.0575 - accuracy: 0.9803 - val_loss: 0.0752 - val_accuracy: 0.9733 - 2s/epoch - 4ms/step
# Epoch 193/1000
# 469/469 - 2s - loss: 0.0573 - accuracy: 0.9802 - val_loss: 0.0749 - val_accuracy: 0.9739 - 2s/epoch - 4ms/step
# Epoch 194/1000
# 469/469 - 2s - loss: 0.0572 - accuracy: 0.9804 - val_loss: 0.0754 - val_accuracy: 0.9743 - 2s/epoch - 4ms/step
# Epoch 195/1000
# 469/469 - 2s - loss: 0.0571 - accuracy: 0.9804 - val_loss: 0.0758 - val_accuracy: 0.9733 - 2s/epoch - 4ms/step
# Epoch 196/1000
# 469/469 - 2s - loss: 0.0570 - accuracy: 0.9803 - val_loss: 0.0749 - val_accuracy: 0.9742 - 2s/epoch - 4ms/step
# Epoch 197/1000
# 469/469 - 2s - loss: 0.0569 - accuracy: 0.9805 - val_loss: 0.0756 - val_accuracy: 0.9740 - 2s/epoch - 4ms/step
# Epoch 198/1000
# 469/469 - 2s - loss: 0.0568 - accuracy: 0.9806 - val_loss: 0.0751 - val_accuracy: 0.9738 - 2s/epoch - 4ms/step
# Epoch 199/1000
# 469/469 - 2s - loss: 0.0566 - accuracy: 0.9806 - val_loss: 0.0749 - val_accuracy: 0.9744 - 2s/epoch - 4ms/step
# Epoch 200/1000
# 469/469 - 2s - loss: 0.0565 - accuracy: 0.9808 - val_loss: 0.0748 - val_accuracy: 0.9743 - 2s/epoch - 4ms/step
# Epoch 201/1000
# 469/469 - 2s - loss: 0.0563 - accuracy: 0.9805 - val_loss: 0.0751 - val_accuracy: 0.9741 - 2s/epoch - 4ms/step
# Epoch 202/1000
# 469/469 - 2s - loss: 0.0563 - accuracy: 0.9808 - val_loss: 0.0752 - val_accuracy: 0.9741 - 2s/epoch - 4ms/step
- val_accuracy: 0.9746 - 2s/epoch - 4ms/step
# Epoch 250/1000
# 469/469 - 2s - loss: 0.0511 - accuracy: 0.9829 - val_loss: 0.0731 - val_accuracy: 0.9742 - 2s/epoch - 4ms/step
# Epoch 251/1000
# 469/469 - 2s - loss: 0.0511 - accuracy: 0.9829 - val_loss: 0.0731 - val_accuracy: 0.9744 - 2s/epoch - 4ms/step
# Epoch 252/1000
# 469/469 - 2s - loss: 0.0509 - accuracy: 0.9827 - val_loss: 0.0727 - val_accuracy: 0.9745 - 2s/epoch - 4ms/step
# Epoch 253/1000
# 469/469 - 2s - loss: 0.0509 - accuracy: 0.9830 - val_loss: 0.0729 - val_accuracy: 0.9745 - 2s/epoch - 4ms/step
# Epoch 254/1000
# 469/469 - 2s - loss: 0.0508 - accuracy: 0.9827 - val_loss: 0.0724 - val_accuracy: 0.9747 - 2s/epoch - 4ms/step
# Epoch 255/1000
# 469/469 - 2s - loss: 0.0507 - accuracy: 0.9828 - val_loss: 0.0729 - val_accuracy: 0.9741 - 2s/epoch - 4ms/step
# Epoch 256/1000
# 469/469 - 2s - loss: 0.0506 - accuracy: 0.9830 - val_loss: 0.0729 - val_accuracy: 0.9753 - 2s/epoch - 4ms/step
# Epoch 257/1000
# 469/469 - 2s - loss: 0.0505 - accuracy: 0.9830 - val_loss: 0.0726 - val_accuracy: 0.9745 - 2s/epoch - 4ms/step
# Epoch 258/1000
# 469/469 - 2s - loss: 0.0504 - accuracy: 0.9831 - val_loss: 0.0723 - val_accuracy: 0.9746 - 2s/epoch - 4ms/step
# Epoch 259/1000
# 469/469 - 2s - loss: 0.0504 - accuracy: 0.9833 - val_loss: 0.0726 - val_accuracy: 0.9750 - 2s/epoch - 4ms/step
# Epoch 260/1000
# 469/469 - 2s - loss: 0.0503 - accuracy: 0.9832 - val_loss: 0.0730 - val_accuracy: 0.9745 - 2s/epoch - 4ms/step
# Epoch 261/1000
# 469/469 - 2s - loss: 0.0502 - accuracy: 0.9833 - val_loss: 0.0726 - val_accuracy: 0.9748 - 2s/epoch - 4ms/step
# Epoch 262/1000
# 469/469 - 2s - loss: 0.0501 - accuracy: 0.9833 - val_loss: 0.0726 - val_accuracy: 0.9752 - 2s/epoch - 4ms/step
# Epoch 263/1000
# 469/469 - 2s - loss: 0.0500 - accuracy: 0.9833 - val_loss: 0.0725 - val_accuracy: 0.9744 - 2s/epoch - 4ms/step
# Epoch 264/1000
# 469/469 - 2s - loss: 0.0498 - accuracy: 0.9836 - val_loss: 0.0724 - val_accuracy: 0.9753 - 2s/epoch - 4ms/step
# Epoch 265/1000
# 469/469 - 2s - loss: 0.0498 - accuracy: 0.9836 - val_loss: 0.0726 - val_accuracy: 0.9746 - 2s/epoch - 4ms/step
# Epoch 266/1000
# 469/469 - 2s - loss: 0.0497 - accuracy: 0.9835 - val_loss: 0.0723 - val_accuracy: 0.9749 - 2s/epoch - 4ms/step
# Epoch 267/1000
# 469/469 - 2s - loss: 0.0496 - accuracy: 0.9835 - val_loss: 0.0724 - val_accuracy: 0.9749 - 2s/epoch - 4ms/step
# Epoch 268/1000
# 469/469 - 2s - loss: 0.0496 - accuracy: 0.9835 - val_loss: 0.0726 - val_accuracy: 0.9744 - 2s/epoch - 4ms/step
# Epoch 269/1000
# 469/469 - 2s - loss: 0.0494 - accuracy: 0.9839 - val_loss: 0.0727 - val_accuracy: 0.9748 - 2s/epoch - 4ms/step
# Epoch 270/1000
# 469/469 - 2s - loss: 0.0494 - accuracy: 0.9834 - val_loss: 0.0725 - val_accuracy: 0.9745 - 2s/epoch - 4ms/step
# Epoch 271/1000
# 469/469 - 2s - loss: 0.0493 - accuracy: 0.9839 - val_loss: 0.0726 - val_accuracy: 0.9743 - 2s/epoch - 4ms/step
# Epoch 272/1000
# 469/469 - 2s - loss: 0.0493 - accuracy: 0.9836 - val_loss: 0.0724 - val_accuracy: 0.9750 - 2s/epoch - 4ms/step
# Epoch 273/1000
# 469/469 - 2s - loss: 0.0491 - accuracy: 0.9836 - val_loss: 0.0728 - val_accuracy: 0.9749 - 2s/epoch - 4ms/step
# Epoch 274/1000
# 469/469 - 2s - loss: 0.0491 - accuracy: 0.9840 - val_loss: 0.0725 - val_accuracy: 0.9744 - 2s/epoch - 4ms/step
# Epoch 275/1000
# 469/469 - 2s - loss: 0.0490 - accuracy: 0.9838 - val_loss: 0.0721 - val_accuracy: 0.9753 - 2s/epoch - 4ms/step
# Epoch 276/1000
# 469/469 - 2s - loss: 0.0489 - accuracy: 0.9838 - val_loss: 0.0726 - val_accuracy: 0.9745 - 2s/epoch - 4ms/step
# Epoch 277/1000
# 469/469 - 2s - loss: 0.0487 - accuracy: 0.9839 - val_loss: 0.0724 - val_accuracy: 0.9748 - 2s/epoch - 4ms/step
# Epoch 278/1000
# 469/469 - 2s - loss: 0.0486 - accuracy: 0.9839 - val_loss: 0.0723 - val_accuracy: 0.9750 - 2s/epoch - 4ms/step
# Epoch 279/1000
# 469/469 - 2s - loss: 0.0486 - accuracy: 0.9839 - val_loss: 0.0722 - val_accuracy: 0.9749 - 2s/epoch - 4ms/step
# Epoch 280/1000
# 469/469 - 2s - loss: 0.0486 - accuracy: 0.9839 - val_loss: 0.0724 - val_accuracy: 0.9746 - 2s/epoch - 4ms/step
# Epoch 281/1000
# 469/469 - 2s - loss: 0.0485 - accuracy: 0.9840 - val_loss: 0.0721 - val_accuracy: 0.9746 - 2s/epoch - 4ms/step
# Epoch 282/1000
# 469/469 - 2s - loss: 0.0485 - accuracy: 0.9839 - val_loss: 0.0723 - val_accuracy: 0.9749 - 2s/epoch - 4ms/step
# Epoch 283/1000
# 469/469 - 2s - loss: 0.0483 - accuracy: 0.9840 - val_loss: 0.0727 - val_accuracy: 0.9745 - 2s/epoch - 4ms/step
# Epoch 284/1000
# 469/469 - 2s - loss: 0.0482 - accuracy: 0.9841 - val_loss: 0.0725 - val_accuracy: 0.9750 - 2s/epoch - 4ms/step
# Epoch 285/1000
# 469/469 - 2s - loss: 0.0481 - accuracy: 0.9841 - val_loss: 0.0723 - val_accuracy: 0.9744 - 2s/epoch - 4ms/step
# Epoch 286/1000
# 469/469 - 2s - loss: 0.0481 - accuracy: 0.9841 - val_loss: 0.0722 - val_accuracy: 0.9744 - 2s/epoch - 4ms/step
# Epoch 287/1000
# 469/469 - 2s - loss: 0.0480 - accuracy: 0.9843 - val_loss: 0.0723 - val_accuracy: 0.9749 - 2s/epoch - 4ms/step
# Epoch 288/1000
# 469/469 - 2s - loss: 0.0480 - accuracy: 0.9842 - val_loss: 0.0723 - val_accuracy: 0.9750 - 2s/epoch - 4ms/step
# Epoch 289/1000
# 469/469 - 2s - loss: 0.0479 - accuracy: 0.9844 - val_loss: 0.0725 - val_accuracy: 0.9738 - 2s/epoch - 4ms/step
# Epoch 290/1000
# 469/469 - 2s - loss: 0.0477 - accuracy: 0.9843 - val_loss: 0.0724 - val_accuracy: 0.9752 - 2s/epoch - 4ms/step
# Epoch 291/1000
# 469/469 - 2s - loss: 0.0478 - accuracy: 0.9846 - val_loss: 0.0721 - val_accuracy: 0.9751 - 2s/epoch - 4ms/step
# Epoch 292/1000
# 469/469 - 2s - loss: 0.0476 - accuracy: 0.9846 - val_loss: 0.0725 - val_accuracy: 0.9748 - 2s/epoch - 4ms/step
# Epoch 293/1000
# 469/469 - 2s - loss: 0.0476 - accuracy: 0.9845 - val_loss: 0.0721 - val_accuracy: 0.9752 - 2s/epoch - 4ms/step
# Epoch 294/1000
# 469/469 - 2s - loss: 0.0475 - accuracy: 0.9844 - val_loss: 0.0722 - val_accuracy: 0.9748 - 2s/epoch - 4ms/step
# Epoch 295/1000
# 469/469 - 2s - loss: 0.0474 - accuracy: 0.9846 - val_loss: 0.0718 - val_accuracy: 0.9746 - 2s/epoch - 4ms/step
# Epoch 296/1000
# 469/469 - 2s - loss: 0.0474 - accuracy: 0.9843 - val_loss: 0.0721 - val_accuracy: 0.9747 - 2s/epoch - 4ms/step
# Epoch 297/1000
# 469/469 - 2s - loss: 0.0472 - accuracy: 0.9847 - val_loss: 0.0719 - val_accuracy: 0.9753 - 2s/epoch - 4ms/step
# Epoch 298/1000
# 469/469 - 2s - loss: 0.0472 - accuracy: 0.9848 - val_loss: 0.0723 - val_accuracy: 0.9744 - 2s/epoch - 4ms/step
# Epoch 299/1000
# 469/469 - 2s - loss: 0.0471 - accuracy: 0.9846 - val_loss: 0.0721 - val_accuracy: 0.9744 - 2s/epoch - 4ms/step
# Epoch 300/1000
# 469/469 - 2s - loss: 0.0470 - accuracy: 0.9846 - val_loss: 0.0722 - val_accuracy: 0.9748 - 2s/epoch - 4ms/step
# Epoch 301/1000
# 469/469 - 2s - loss: 0.0470 - accuracy: 0.9848 - val_loss: 0.0722 - val_accuracy: 0.9748 - 2s/epoch - 4ms/step
# Epoch 302/1000
# 469/469 - 2s - loss: 0.0469 - accuracy: 0.9849 - val_loss: 0.0717 - val_accuracy: 0.9750 - 2s/epoch - 4ms/step
# Epoch 303/1000
# 469/469 - 2s - loss: 0.0468 - accuracy: 0.9846 - val_loss: 0.0721 - val_accuracy: 0.9749 - 2s/epoch - 4ms/step
# Epoch 304/1000
# 469/469 - 2s - loss: 0.0467 - accuracy: 0.9850 - val_loss: 0.0722 - val_accuracy: 0.9750 - 2s/epoch - 4ms/step
# Epoch 305/1000
# 469/469 - 2s - loss: 0.0467 - accuracy: 0.9848 - val_loss: 0.0718 - val_accuracy: 0.9755 - 2s/epoch - 4ms/step
# Epoch 306/1000
# 469/469 - 2s - loss: 0.0466 - accuracy: 0.9849 - val_loss: 0.0720 - val_accuracy: 0.9750 - 2s/epoch - 4ms/step
# Epoch 307/1000
# 469/469 - 2s - loss: 0.0465 - accuracy: 0.9847 - val_loss: 0.0729 - val_accuracy: 0.9744 - 2s/epoch - 4ms/step
# Epoch 308/1000
# 469/469 - 2s - loss: 0.0464 - accuracy: 0.9849 - val_loss: 0.0714 - val_accuracy: 0.9752 - 2s/epoch - 4ms/step
# Epoch 309/1000
# 469/469 - 2s - loss: 0.0464 - accuracy: 0.9850 - val_loss: 0.0715 - val_accuracy: 0.9754 - 2s/epoch - 4ms/step
# Epoch 310/1000
# 469/469 - 2s - loss: 0.0463 - accuracy: 0.9850 - val_loss: 0.0715 - val_accuracy: 0.9754 - 2s/epoch - 4ms/step
# Epoch 311/1000
# 469/469 - 2s - loss: 0.0463 - accuracy: 0.9850 - val_loss: 0.0718 - val_accuracy: 0.9748 - 2s/epoch - 4ms/step
# Epoch 312/1000
# 469/469 - 2s - loss: 0.0462 - accuracy: 0.9851 - val_loss: 0.0724 - val_accuracy: 0.9751 - 2s/epoch - 4ms/step
# Epoch 313/1000
# 469/469 - 2s - loss: 0.0461 - accuracy: 0.9850 - val_loss: 0.0719 - val_accuracy: 0.9749 - 2s/epoch - 4ms/step
# Epoch 314/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 history = model.fit(x_train_reduced, y_train, validation_data=(x_test_reduced, y_test), batch_size=128, epochs=1000, verbose=2)
#
# File ~/anaconda3/envs/tensor-koopman/lib/python3.8/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tensor-koopman/lib/python3.8/site-packages/keras/engine/training.py:1650, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1642 with tf.profiler.experimental.Trace(
#    1643     "train",
#    1644     epoch_num=epoch,
#    (...)
#    1647     _r=1,
#    1648 ):
#    1649     callbacks.on_train_batch_begin(step)
# -> 1650     tmp_logs = self.train_function(iterator)
#    1651     if data_handler.should_sync:
#    1652         context.async_wait()
#
# File ~/anaconda3/envs/tensor-koopman/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tensor-koopman/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:880, in Function.__call__(self, *args, **kwds)
#     877 compiler = "xla" if self._jit_compile else "nonXla"
#     879 with OptionalXlaContext(self._jit_compile):
# --> 880   result = self._call(*args, **kwds)
#     882 new_tracing_count = self.experimental_get_tracing_count()
#     883 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/tensor-koopman/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:912, in Function._call(self, *args, **kwds)
#     909   self._lock.release()
#     910   # In this case we have created variables on the first call, so we run the
#     911   # defunned version which is guaranteed to never create variables.
# --> 912   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     913 elif self._variable_creation_fn is not None:
#     914   # Release the lock early so that multiple threads can perform the call
#     915   # in parallel.
#     916   self._lock.release()
#
# File ~/anaconda3/envs/tensor-koopman/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:134, in TracingCompiler.__call__(self, *args, **kwargs)
#     131 with self._lock:
#     132   (concrete_function,
#     133    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134 return concrete_function._call_flat(
#     135     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File ~/anaconda3/envs/tensor-koopman/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:1745, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1741 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1742 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1743     and executing_eagerly):
#    1744   # No tape is watching; skip to running the function.
# -> 1745   return self._build_call_outputs(self._inference_function.call(
#    1746       ctx, args, cancellation_manager=cancellation_manager))
#    1747 forward_backward = self._select_forward_and_backward_functions(
#    1748     args,
#    1749     possible_gradient_type,
#    1750     executing_eagerly)
#    1751 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/tensor-koopman/lib/python3.8/site-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py:378, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     376 with _InterpolateFunctionError(self):
#     377   if cancellation_manager is None:
# --> 378     outputs = execute.execute(
#     379         str(self.signature.name),
#     380         num_outputs=self._num_outputs,
#     381         inputs=args,
#     382         attrs=attrs,
#     383         ctx=ctx)
#     384   else:
#     385     outputs = execute.execute_with_cancellation(
#     386         str(self.signature.name),
#     387         num_outputs=self._num_outputs,
#    (...)
#     390         ctx=ctx,
#     391         cancellation_manager=cancellation_manager)
#
# File ~/anaconda3/envs/tensor-koopman/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# KeyboardInterrupt:

# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.debugging.set_log_device_placement(False)
gpus = tf.config.list_physical_devices('GPU')

from sklearn.decomposition import PCA
import numpy as np
import tensorflow as tf

# Load MNIST data.
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Preprocessing: normalize pixel values to be between 0 and 1.
x_train = x_train / 255.0
x_test = x_test / 255.0

# Shuffle training data.
shuffle_index = np.random.permutation(len(x_train))
x_train, y_train = x_train[shuffle_index], y_train[shuffle_index]

# Convert target labels to binary classification (digit < 5 or digit >= 5).
y_train = (y_train < 5)
y_test = (y_test < 5)

# Convert labels to one-hot encoding.
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# Track the data type of x_train.
dataType = x_train.dtype
print(f"Data type: {dataType}")

# Track the data type of y_test.
labelType = y_test.dtype
print(f"Data type: {labelType}")

# Print the one-hot encoded label for the first training example.
print(y_train[0])

# Instantiate the training dataset.
x_train = np.reshape(x_train, (-1, 784))
x_test = np.reshape(x_test, (-1, 784))

# Perform PCA to reduce dimensionality of x_train.
pca = PCA(n_components=0.7)  # retain 95% of variance
x_train_reduced = pca.fit_transform(x_train.reshape(x_train.shape[0], -1))
x_test_reduced = pca.transform(x_test.reshape(x_test.shape[0], -1))

# Print the dimensions of the original and reduced datasets.
print("Original dimensions:", x_train.shape)
print("Reduced dimensions:", x_train_reduced.shape)

node_set = [16, 32, 64, 128, 256, 1024]


from tensorflow import keras

for node_num in node_set:
    for training_id in range(10):
        inputs = keras.Input(shape=(26,), name="digits")
        x = keras.layers.Dense(node_num, activation="relu", kernel_initializer="uniform",bias_initializer="uniform")(inputs)
        outputs = keras.layers.Dense(2, name="predictions",kernel_initializer="uniform",bias_initializer="uniform")(x)
        model = keras.Model(inputs=inputs, outputs=outputs)
        
        # Instantiate an optimizer.
        optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
        # Instantiate a loss function.
        loss_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
        # Compile the model
        model.compile(optimizer=optimizer, loss=loss_fn,  metrics=["accuracy"])        
        
        weight_record = []
        print("Start training at width %d, id %d" % (node_num, training_id))
        for epoch in range(200):
            history = model.fit(x_train_reduced, y_train, validation_data=(x_test_reduced, y_test), batch_size=128, epochs=1, verbose=0)
            weight_record.append(model.trainable_weights)
        np.save('learn_output/weight_%d_%d.npy' % (node_num, training_id), weight_record)
        del weight_record
        gc.collect()
# Out:
# Num GPUs Available:  1
# Data type: float64
# Data type: float32
# [1. 0.]
# Original dimensions: (60000, 784)
# Reduced dimensions: (60000, 26)
# Start training at width 16, id 0
